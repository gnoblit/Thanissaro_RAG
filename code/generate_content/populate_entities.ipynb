# %%
import polars as pl

import numpy as np
import json
import git
import os
# Get absolute file path
git_repo = git.Repo(os.getcwd(), search_parent_directories=True)
git_root = git_repo.git.rev_parse("--show-toplevel")

from google import genai
from google.genai.types import HarmBlockThreshold, HarmCategory, SafetySetting, GenerateContentConfig


from tqdm.notebook import tqdm

import jsonlines

# %%
# Params
PRINT = False

write_path = git_root + "/" + "data/generated/information_extraction.jsonl"

# %%
# Pull in Sutta text

path_to_data = "data/web/thanissaro_scraped.jsonl"
path_to_data = git_root + "/" + path_to_data

data = []

with jsonlines.open(path_to_data) as reader:
    for obj in reader:
        data.append({"text": obj["sutta_text"],
                     "sutta":obj["sutta"]} )

df = pl.from_dicts(data)
df.head()
# Out:
# shape: (5, 2)
# ┌─────────────────────────────────┬──────────┐
# │ text                            ┆ sutta    │
# │ ---                             ┆ ---      │
# │ str                             ┆ str      │
# ╞═════════════════════════════════╪══════════╡
# │ “Monks, these three persons ar… ┆ AN 3:116 │
# │ Once the Blessed One was livin… ┆ AN 7:58  │
# │ This was said by the Blessed O… ┆ Iti 48   │
# │ On one occasion the Blessed On… ┆ AN 3:126 │
# │ “Monks, without abandoning six… ┆ AN 6:73  │
# └─────────────────────────────────┴──────────┘

# %%
# Provide API
API_PATH = "/home/graham/.config/my_api_keys"
with open(API_PATH, 'r') as f:
    keys = f.read()
gemini_api = json.loads(keys)['google_gemini']
client = genai.Client(api_key=gemini_api)

# %%
safety_settings = [
    SafetySetting(
        category=HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT,
        threshold=HarmBlockThreshold.BLOCK_NONE,
    ),
    SafetySetting(
        category=HarmCategory.HARM_CATEGORY_HARASSMENT,
        threshold=HarmBlockThreshold.BLOCK_NONE,
    ),
    SafetySetting(
        category=HarmCategory.HARM_CATEGORY_HATE_SPEECH,
        threshold=HarmBlockThreshold.BLOCK_NONE,
    ),
    SafetySetting(
        category=HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT,
        threshold=HarmBlockThreshold.BLOCK_NONE,
    ),
]

# %%
bad_extensive = []
SYSTEM_INSTRUCTION = """You are an expert data extractor specializing in Buddhist philosophy and the Pali Canon. Your primary function is to analyze a Sutta text and extract a knowledge graph based **exclusively** on the information contained within that text. You will identify the internal ontology—the entities, processes, relationships, and concepts—as they are defined and related *within the Sutta itself*.

Your output will be used to generate a knowledge graph for Graph RAG, so precision, adherence to the text, and correct formatting are paramount.

**Core Rules:**

1.  **Text-Only Extraction:** All extracted information **must** be directly present in or clearly implied by the provided Sutta text. Do not introduce any external Buddhist knowledge, interpretations, or definitions.
2.  **Internal Ontology:** Focus on how the Sutta defines its own terms and relationships. Pay close attention to metaphors, where one concept is defined in relation to another.
3.  **Graph-Ready Relationships:** Every relationship must be a "triple" with a single, specific source and a single, specific target.
4.  **Relevance Filter:** Extract only entities, processes, and relationships that are thematically significant to the Sutta's core message and its practical teachings. Ignore incidental details (e.g., "a monk sat down").

---

**ANALYSIS INSTRUCTIONS**

For the Sutta text provided below, perform the following extraction steps and format the output as a single Python dictionary.

**1. Identify Entities**
Extract significant nouns or concepts that function as "things" in the Sutta. An entity can be a being, an abstract concept treated as an object, a mental state, or a place.

*   **`name`**: The name of the entity.
*   **`type`**: [+] A broad category. Use the following **non-exhaustive list as a guide** to inform your judgment: 'Person', 'Group', 'Mental State', 'Concept as Object', 'Location', 'Physical Object', 'Figurative Language'.
*   **`description`**: A summary of the entity based *only* on its description in this text. If not described, state "Not described in this text."
*   **`goal`**: Any stated goal of the entity.
*   **`intention`**: Any stated intention of the entity.
*   **`practice_link`**: How this entity relates to a Buddhist practice, if mentioned.

**2. Identify Processes**
Extract significant actions, events, or transformations. A process describes something happening over time and typically involves one or more entities.

*   **`name`**: A concise name for the process (e.g., 'The Arising of Suffering', 'Cultivating the Path').
*   **`description`**: A high-level explanation of the process as described in the text.
*   **`impacted_entities`**: A list of entity names impacted by this process.
*   **`steps`**: Deconstruct the process into a sequence of events.
    *   **`step_description`**: Description of the step.
    *   **`starting_state`**: The state or entity before the action.
    *   **`action`**: The action being performed.
    *   **`resulting_state`**: The state or entity after the action.
*   **`goal`**: The stated or implied goal of the process.
*   **`practice_link`**: How this process relates to a Buddhist practice, if mentioned.

**3. Identify Relationships**
Extract directed connections between entities and/or processes. These are the edges of your knowledge graph.

[+] **Guiding Principles for Relationship Labels:** Before extracting, understand these principles for creating the `relationship_label`.
*   **Be Active & Simple:** Formulate the label as a concise, active verb phrase, standardized to its base form (e.g., use `LEADS_TO` instead of "leads to" or "led to").
*   **Capture the Nuance:** The label should be as specific as the text allows. Instead of a generic `RELATES_TO`, prefer `IS_A_CAUSE_OF`, `IS_A_COMPONENT_OF`, `IS_COMPARED_TO`, or `IS_AN_ANTIDOTE_FOR`.
*   **Common Relation Types to Look For (Non-Exhaustive List):**
    *   **Causal:** `CAUSES`, `LEADS_TO`, `IS_A_CONDITION_FOR`, `RESULTS_FROM`
    *   **Compositional:** `IS_PART_OF`, `CONSISTS_OF`, `IS_AN_EXAMPLE_OF`
    *   **Social/Narrative:** `INTERACTS_WITH`, `ASKS_QUESTION_OF`, `TEACHES`, `RESIDES_IN`
    *   **Comparative:** `IS_COMPARED_TO`, `IS_SUPERIOR_TO`, `IS_OPPOSITE_OF`
    *   **Definitional:** `IS_DEFINED_AS`, `IS_A_TYPE_OF`

Now, extract the relationships with the following attributes:
*   **`source`**: The name of the source Entity or Process.
*   **`target`**: The name of the target Entity or Process.
*   **`relationship_label`**: A short, general, verb-based label for the relationship, following the principles above (e.g., 'LEADS_TO', 'IS_A', 'CAUSES'). This will be the predicate in your graph triple.
*   **`specific_description`**: A detailed sentence describing how the text *specifically* frames this relationship. Capture the unique context and nuance.
*   **`medium`**: The entity or process that enables or facilitates the relationship, if specified.
*   **`outcome`**: The result of the relationship, if different from the target.

**4. Identify Concepts**
Extract key doctrinal or philosophical ideas being explained. A concept is a teaching or a principle, whereas an entity is treated as a "thing" within the Sutta's narrative.

*   **`name`**: The name of the concept (e.g., 'The Four Noble Truths', 'Impermanence').
*   **`description`**: An explanation of the concept based *only* on how it is presented in this Sutta.
*   **`practice_link`**: How this concept is connected to a specific practice.
*   **`goal`**: The goal or purpose associated with understanding this concept.

---

**OUTPUT FORMAT**

Provide your analysis in a single Python dictionary. Do not include any explanatory text before or after the dictionary. If a field has no information, use `None` for single values or an empty list `[]` for lists. Do not use a ```python delimiter.

{
  "entities": [
    {
      "name": "...",
      "type": "...",
      "description": "...",
      "goal": "...",
      "intention": "...",
      "practice_link": "..."
    }
  ],
  "processes": [
    {
      "name": "...",
      "description": "...",
      "impacted_entities": ["..."],
      "steps": [
        {
          "step_description": "...",
          "starting_state": "...",
          "action": "...",
          "resulting_state": "..."
        }
      ],
      "goal": "...",
      "practice_link": "..."
    }
  ],
  "relationships": [
    {
      "source": "...",
      "target": "...",
      "relationship_label": "...",
      "specific_description": "...",
      "medium": "...",
      "outcome": "..."
    }
  ],
  "concepts": [
    {
      "name": "...",
      "description": "...",
      "practice_link": "...",
      "goal": "..."
    }
  ]
}"""

# %%
# # Load existing data
# existing_data = pl.read_ndjson(write_path)
# existing_data = existing_data.filter(
#     (pl.col("model_name").eq(model_extensive.model_name) & pl.col("prompt_type").eq("extensive"))
# )
# data_extensive = pl.from_dicts(data).filter(
#     pl.col("sutta").is_in(existing_data["sutta"]).not_()
# )
# print(f"Size of data to perform inference on: {data_extensive.height}")
# data_extensive.head()
# Out:
# Size of data to perform inference on: 496
# shape: (5, 5)
# ┌─────────────────────────────────┬───────────┬──────────────┬────────────┬─────────────┐
# │ text                            ┆ sutta     ┆ model_output ┆ model_name ┆ prompt_type │
# │ ---                             ┆ ---       ┆ ---          ┆ ---        ┆ ---         │
# │ str                             ┆ str       ┆ str          ┆ str        ┆ str         │
# ╞═════════════════════════════════╪═══════════╪══════════════╪════════════╪═════════════╡
# │ Then Ven. Sāriputta went to t…  ┆ SN 55:5   ┆ null         ┆ null       ┆ null        │
# │ I have heard that on one occas… ┆ AN 10:165 ┆ null         ┆ null       ┆ null        │
# │ An example of how pointed the … ┆ AN 5:191  ┆ null         ┆ null       ┆ null        │
# │ I have heard that on one occas… ┆ SN 4:8    ┆ null         ┆ null       ┆ null        │
# │ I have heard that on one occas… ┆ Ud 3:1    ┆ null         ┆ null       ┆ null        │
# └─────────────────────────────────┴───────────┴──────────────┴────────────┴─────────────┘

# %%
model_id = 'gemini-2.5-flash-preview-04-17'

config = GenerateContentConfig(
      temperature=0.95,
      safety_settings=safety_settings,
      system_instruction=SYSTEM_INSTRUCTION
)

# %%
bad = []
data = df.to_dicts()
for el_ in tqdm(data):
    try:
        response = client.models.generate_content(
            model=model_id,
            config=config,
            contents=el_['text']

        ).text

        el_.update(
            {
                "model_output": response,
                "model_id": model_id
            }
        )

        if PRINT == False:
            with jsonlines.open(write_path, mode='a') as writer:
                writer.write(el_) 
    except Exception as e:
        print(f"""{el_["sutta"]}: {e}""")
        bad_extensive.append(el_)
# Out:
#   0%|          | 0/2815 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 5
#       3 for el_ in tqdm(data_extensive):
#       4     try:
# ----> 5         response = client.models.generate_content(
#       6             model=model_id,
#       7             config=config,
#       8             contents=el_['text']
#       9
#      10         ).text
#      12         el_.update(
#      13             {
#      14                 "model_output": response,
#      15                 "model_id": model_id
#      16             }
#      17         )
#      19         if PRINT == False:
#
# File ~/projects/buddhism/Thanissaro_RAG/venv_thanissaro_rag/lib/python3.10/site-packages/google/genai/models.py:5630, in Models.generate_content(self, model, contents, config)
#    5628 while remaining_remote_calls_afc > 0:
#    5629   i += 1
# -> 5630   response = self._generate_content(
#    5631       model=model, contents=contents, config=parsed_config
#    5632   )
#    5633   logger.info(f'AFC remote call {i} is done.')
#    5634   remaining_remote_calls_afc -= 1
#
# File ~/projects/buddhism/Thanissaro_RAG/venv_thanissaro_rag/lib/python3.10/site-packages/google/genai/models.py:4593, in Models._generate_content(self, model, contents, config)
#    4590 request_dict = _common.convert_to_dict(request_dict)
#    4591 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4593 response_dict = self._api_client.request(
#    4594     'post', path, request_dict, http_options
#    4595 )
#    4597 if self._api_client.vertexai:
#    4598   response_dict = _GenerateContentResponse_from_vertex(
#    4599       self._api_client, response_dict
#    4600   )
#
# File ~/projects/buddhism/Thanissaro_RAG/venv_thanissaro_rag/lib/python3.10/site-packages/google/genai/_api_client.py:755, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#     745 def request(
#     746     self,
#     747     http_method: str,
#    (...)
#     750     http_options: Optional[HttpOptionsOrDict] = None,
#     751 ) -> Union[BaseResponse, Any]:
#     752   http_request = self._build_request(
#     753       http_method, path, request_dict, http_options
#     754   )
# --> 755   response = self._request(http_request, stream=False)
#     756   json_response = response.json
#     757   if not json_response:
#
# File ~/projects/buddhism/Thanissaro_RAG/venv_thanissaro_rag/lib/python3.10/site-packages/google/genai/_api_client.py:677, in BaseApiClient._request(self, http_request, stream)
#     673   return HttpResponse(
#     674       response.headers, response if stream else [response.text]
#     675   )
#     676 else:
# --> 677   response = self._httpx_client.request(
#     678       method=http_request.method,
#     679       url=http_request.url,
#     680       headers=http_request.headers,
#     681       content=data,
#     682       timeout=http_request.timeout,
#     683   )
#     684   errors.APIError.raise_for_response(response)
#     685   return HttpResponse(
#     686       response.headers, response if stream else [response.text]
#     687   )
#
# File ~/projects/buddhism/Thanissaro_RAG/venv_thanissaro_rag/lib/python3.10/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)
#     823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/projects/buddhism/Thanissaro_RAG/venv_thanissaro_rag/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/projects/buddhism/Thanissaro_RAG/venv_thanissaro_rag/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/projects/buddhism/Thanissaro_RAG/venv_thanissaro_rag/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/projects/buddhism/Thanissaro_RAG/venv_thanissaro_rag/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/projects/buddhism/Thanissaro_RAG/venv_thanissaro_rag/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/projects/buddhism/Thanissaro_RAG/venv_thanissaro_rag/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~/projects/buddhism/Thanissaro_RAG/venv_thanissaro_rag/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~/projects/buddhism/Thanissaro_RAG/venv_thanissaro_rag/lib/python3.10/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~/projects/buddhism/Thanissaro_RAG/venv_thanissaro_rag/lib/python3.10/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~/projects/buddhism/Thanissaro_RAG/venv_thanissaro_rag/lib/python3.10/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~/projects/buddhism/Thanissaro_RAG/venv_thanissaro_rag/lib/python3.10/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~/projects/buddhism/Thanissaro_RAG/venv_thanissaro_rag/lib/python3.10/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/projects/buddhism/Thanissaro_RAG/venv_thanissaro_rag/lib/python3.10/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File /usr/lib/python3.10/ssl.py:1288, in SSLSocket.recv(self, buflen, flags)
#    1284     if flags != 0:
#    1285         raise ValueError(
#    1286             "non-zero flags not allowed in calls to recv() on %s" %
#    1287             self.__class__)
# -> 1288     return self.read(buflen)
#    1289 else:
#    1290     return super().recv(buflen, flags)
#
# File /usr/lib/python3.10/ssl.py:1161, in SSLSocket.read(self, len, buffer)
#    1159         return self._sslobj.read(len, buffer)
#    1160     else:
# -> 1161         return self._sslobj.read(len)
#    1162 except SSLError as x:
#    1163     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
SYSTEM_INSTRUCTION_SIMPLE = """
You are an expert in Buddhist philosophy and the Pali Canon. Your task is to analyze the provided Sutta text and extract its key elements, focusing on the ontology of entities, processes, and relationships described within the text itself. Provide the information in a structured format. You are helping me to generate a knowledge graph for Graph RAG and document interaction for the Pali Canon. The Pali Canon is a set of suttas that are related to Buddhism. Importantly, the Buddha and his monks often spoke in metaphor. This means that entities in the Canon exist that are defined relative to other entities. There is effectively an ontology, a set of entities and processes as well as the relationships among them, that is defined within the Pali Canon itself. It is your job to help identify these entities, processes, and relationships. You should focus on extracting relationships that exist in the current Sutta. Do not include any external information in the extraction. You should focus on only extracting graph-ready information in which each relationship should have only a single source and target.

For each sutta that I provide you with follow these instructions:

**Instructions:**
1.  **Read the Sutta:** Carefully read the Sutta text provided below.
2.  **Extract Entities:** Identify significant entities (things, concepts, processes, beings, etc.) in the Sutta. For each, give its name and a description based only on what the Sutta itself says.
4.  **Extract Relationships:** Identify key and important relationships between entities and processes in the Sutta. For each, give a relationship name, a description from the Sutta, the source, the target, and a relationship type (e.g., causal, associative, constituent, etc.).
5.  **Extract Concepts:** Identify key Buddhist concepts. For each, give its name, a description based on the Sutta.
6.  **Structured Output:** Return the extracted information as a Python dictionary with the following structure:

 {
      "entities": [
        { 
        "name": "[Entity Name]", 
        "type": "[Entity Type]", 
        "description": "[Entity Description]" 
        },
         ...
      ],
      "relationships": [
        { 
        "name": "[Relationship Name]", 
        "specific_description": "[Relationship Description]", 
        "general_type": "[Relationship Type]", 
        "source": "[Source]", 
        "target": "[Target]" 
        },
         ...
      ],
      "concepts": [
        { 
        "name": "[Concept Name]", 
        "description": "[Concept Description]", 
        "type": "[verbatim/summary/inference]"
        },
         ...
      ]
    }
"""

model_simple = genai.GenerativeModel(
    "gemini-2.0-flash-exp",
    system_instruction=SYSTEM_INSTRUCTION_SIMPLE
    )

# %%
# Load existing data
data = []

with jsonlines.open(path_to_data) as reader:
    for obj in reader:
        data.append({"text": obj["sutta_text"],
                     "sutta":obj["sutta"]} )
        
existing_data = pl.read_ndjson(write_path)
existing_data = existing_data.filter(
    (pl.col("model_name").eq(model_simple.model_name) & pl.col("prompt_type").eq("simple"))
)
data_simple = pl.from_dicts(data).filter(
    pl.col("sutta").is_in(existing_data["sutta"]).not_()
)
print(f"Size of data to perform inference on: {data_simple.height}")
data_simple.head()
# Out:
# Size of data to perform inference on: 1395
# shape: (5, 2)
# ┌─────────────────────────────────┬──────────┐
# │ text                            ┆ sutta    │
# │ ---                             ┆ ---      │
# │ str                             ┆ str      │
# ╞═════════════════════════════════╪══════════╡
# │ “Monks, these three persons ar… ┆ AN 3:116 │
# │ Once the Blessed One was livin… ┆ AN 7:58  │
# │ This was said by the Blessed O… ┆ Iti 48   │
# │ On one occasion the Blessed On… ┆ AN 3:126 │
# │ “Monks, without abandoning six… ┆ AN 6:73  │
# └─────────────────────────────────┴──────────┘

# %%
bad_simple = []
data_simple = data_simple.to_dicts()
for el_ in tqdm(data_simple):
    try:
        el_["model_output"] = model_simple.generate_content(
            el_["text"]
        ).text
        el_["model_name"] = model_simple.model_name
        el_["prompt_type"] = "simple"

        if PRINT == False:
            with jsonlines.open(write_path, mode='a') as writer:
                writer.write(el_) 
    except Exception as e:
        print(f"""{el_["sutta"]}: {e}""")
        bad_simple.append(el_)
# Out:
#   0%|          | 0/1395 [00:00<?, ?it/s]
# SN 35:82: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 4. Meaning that the model was reciting from copyrighted material.

# %%
SYSTEM_INSTRUCTION_GENERAL = """
**Instructions:**
You are an expert in analyzing documents and extracting knowledge. Your task is to analyze the following document and identify its key elements, focusing on information explicitly stated within the document itself. Do not use prior knowledge or information not contained in the text.

The dictionary should have the following keys:
* `"main_topics"`: A list of strings representing the main topics or themes of the document.
* `"key_entities"`: A dictionary where each key is a concept or instance name and its value is either "concept" or "instance."
* `"local_relationships"`: A list of dictionaries, where each dictionary represents a relationship with keys: `"entity1"`, `"relation_phrase"`, `"entity2"` and an optional key `"relation_type"` if the relationship type is explicit in the text.
* `"descriptive_phrases"`: A dictionary where each key is an entity and its value is a list of strings representing its descriptive phrases.
* `"local_definitions"`: A dictionary where each key is an entity and its value is the string representing its local definition(s), including direct quotes from the document if available.
* `"key_phrases"`: A list of key phrases and recurring terminology from the document.

**Example Output:**
Here's an example of what the output should look like:

**Instructions:**
For this document, please identify and list the following, formatted as a Python dictionary. Follow the schema provided below strictly and only output valid JSON which is a python dictionary.

The dictionary should have the following keys:
* `"main_topics"`: A list of strings representing the main topics or themes of the document.
* `"key_entities"`: A dictionary where each key is a concept or instance name and its value is either "concept" or "instance."
* `"local_relationships"`: A list of dictionaries, where each dictionary represents a relationship with keys: `"entity1"`, `"relation_phrase"`, `"entity2"` and an optional key `"relation_type"` if the relationship type is explicit in the text.
* `"descriptive_phrases"`: A dictionary where each key is an entity and its value is a list of strings representing its descriptive phrases.
* `"local_definitions"`: A dictionary where each key is an entity and its value is the string representing its local definition(s), including direct quotes from the document if available.
* `"key_phrases"`: A list of key phrases and recurring terminology from the document.

**Example Output:**

Document: "There, monks, a monk dwells contemplating the body, ardent, clearly knowing, mindful, having put away covetousness and grief in the world. He dwells contemplating feelings, ardent, clearly knowing, mindful, having put away covetousness and grief in the world. He dwells contemplating mind, ardent, clearly knowing, mindful, having put away covetousness and grief in the world. He dwells contemplating mental objects, ardent, clearly knowing, mindful, having put away covetousness and grief in the world."

Answer: 

{
    "main_topics": ["mindfulness", "contemplation", "meditation"],
    "key_entities": {
        "monk": "concept",
        "body": "concept",
        "feelings": "concept",
        "mind": "concept",
        "mental objects": "concept",
        "covetousness": "concept",
        "grief": "concept",
        "world": "concept"
    },
    "local_relationships": [
        {
            "entity1": "monk",
            "relation_phrase": "dwells contemplating",
            "entity2": "body",
            "relation_type": "contemplation"
        },
        {
            "entity1": "monk",
             "relation_phrase": "dwells contemplating",
             "entity2": "feelings",
            "relation_type": "contemplation"
        },
      {
             "entity1": "monk",
              "relation_phrase": "dwells contemplating",
             "entity2": "mind",
            "relation_type": "contemplation"
        },
       {
             "entity1": "monk",
             "relation_phrase": "dwells contemplating",
             "entity2": "mental objects",
            "relation_type": "contemplation"
        },
        {
            "entity1": "monk",
            "relation_phrase": "having put away",
             "entity2": "covetousness",
             "relation_type": "put away"
        },
        {
            "entity1": "monk",
             "relation_phrase": "having put away",
            "entity2": "grief",
            "relation_type": "put away"
        },
         {
            "entity1": "covetousness",
            "relation_phrase": "in",
            "entity2": "world"
         },
          {
            "entity1": "grief",
             "relation_phrase": "in",
             "entity2": "world"
        }
    ],
     "descriptive_phrases": {
        "monk":["ardent", "clearly knowing", "mindful"],
        "body": ["body"],
        "feelings": ["feelings"],
        "mind":["mind"],
        "mental objects": ["mental objects"]
      },
    "local_definitions": {},
    "key_phrases": ["dwells contemplating", "having put away", "covetousness and grief"]
}
"""

model_general = genai.GenerativeModel(
    "gemini-2.0-flash-exp",
    system_instruction=SYSTEM_INSTRUCTION_GENERAL
    )

# %%
# Load existing data
data = []

with jsonlines.open(path_to_data) as reader:
    for obj in reader:
        data.append({"text": obj["sutta_text"],
                     "sutta":obj["sutta"]} )
        
existing_data = pl.read_ndjson(write_path)
existing_data = existing_data.filter(
    (pl.col("model_name").eq(model_general.model_name) & pl.col("prompt_type").eq("general"))
)
data_general = pl.from_dicts(data).filter(
    pl.col("sutta").is_in(existing_data["sutta"]).not_()
)
print(f"Size of data to perform inference on: {data_general.height}")
data_general.head()
# Out:
# Size of data to perform inference on: 1395
# shape: (5, 2)
# ┌─────────────────────────────────┬──────────┐
# │ text                            ┆ sutta    │
# │ ---                             ┆ ---      │
# │ str                             ┆ str      │
# ╞═════════════════════════════════╪══════════╡
# │ “Monks, these three persons ar… ┆ AN 3:116 │
# │ Once the Blessed One was livin… ┆ AN 7:58  │
# │ This was said by the Blessed O… ┆ Iti 48   │
# │ On one occasion the Blessed On… ┆ AN 3:126 │
# │ “Monks, without abandoning six… ┆ AN 6:73  │
# └─────────────────────────────────┴──────────┘

# %%
bad_general = []
data_general = data_general.to_dicts()
for el_ in tqdm(data_general):
    try:
        el_["model_output"] = model_general.generate_content(
            el_["text"]
        ).text
        el_["model_name"] = model_general.model_name
        el_["prompt_type"] = "general"

        if PRINT == False:
            with jsonlines.open(write_path, mode='a') as writer:
                writer.write(el_) 
    except Exception as e:
        print(f"""{el_["sutta"]}: {e}""")
        bad_general.append(el_)
# Out:
#   0%|          | 0/1395 [00:00<?, ?it/s]

# %%
SYSTEM_INSTRUCTION_THINKING = """
I need to extract a complete ontology from the following document, which is a sutta from the Buddhist Pali Canon. This ontology is defined internally among all of the documents that you are going to see but you are only going to see each one at a time. This means you will not get to see all documents simultaneously to construct the ontology. 

I think an ontology consists of two main elements. First, entities, which may be objects, concepts, or processes, and second, relationships between those entities. This means I think of the ontology as a sort of graph of nodes (entities) and connections between nodes (relationships). I call this an ontology because "meaning" of something in such a system can be explained in terms of other entities and relationships. This is how things are often explained in the Pali Canon, so it seems to fit. But if you think I am missing some element, please fill it in. 

I want to do this because I want to understand that ontology. I think Buddhism is a religion that seeks to do something particularly unique and interesting in terms of human phenomenology, psychology, and experience. It however often does this through metaphor. I am hoping that identifying this ontology will help me to understand the meaning of those metaphors in terms of my own life and general human experience. This is my ultimate goal.

Your task is to generate a python dictionary that will help me to identify that ontology. I ultimately want to use the data in the dictionaries you generate to construct a graph structure that maps this ontology out and perhaps to use with RAG (retrieval augmented generation). 

Please do your best and make the decisions that make the most sense to you for helping me in my ultimate goal of understanding Buddhist ontology.
"""

model_thinking = genai.GenerativeModel(
    "gemini-2.0-flash-thinking-exp",
    system_instruction=SYSTEM_INSTRUCTION_THINKING
    )

# %%
# Load existing data
data = []

with jsonlines.open(path_to_data) as reader:
    for obj in reader:
        data.append({"text": obj["sutta_text"],
                     "sutta":obj["sutta"]} )
        
existing_data = pl.read_ndjson(write_path)
existing_data = existing_data.filter(
    (pl.col("model_name").eq(model_thinking.model_name) & pl.col("prompt_type").eq("thinking"))
)
data_thinking = pl.from_dicts(data).filter(
    pl.col("sutta").is_in(existing_data["sutta"]).not_()
)
print(f"Size of data to perform inference on: {data_thinking.height}")
data_thinking.head()
# Out:
# Size of data to perform inference on: 198
# shape: (5, 2)
# ┌─────────────────────────────────┬──────────┐
# │ text                            ┆ sutta    │
# │ ---                             ┆ ---      │
# │ str                             ┆ str      │
# ╞═════════════════════════════════╪══════════╡
# │ I have heard that on one occas… ┆ DN 16    │
# │ Four times, five, I ran amok f… ┆ Thig 6:8 │
# │ Then Ven. Anuruddha went to Ve… ┆ AN 3:131 │
# │ I have heard that on one occas… ┆ SN 48:53 │
# │ I have heard that at one time … ┆ AN 3:137 │
# └─────────────────────────────────┴──────────┘

# %%
print(existing_data.head()["model_output"][0])
# Out:
# Here's a breakdown of the thinking process to arrive at the ontology for the given sutta:
#
# 1. **Understand the Goal:** The user wants to extract an ontology (entities and relationships) from a single Buddhist sutta. The ultimate aim is to understand Buddhist concepts related to human experience and psychology. The output should be a Python dictionary.
#
# 2. **Identify Core Entities:** The sutta explicitly mentions three "persons" as the central entities. These categories of persons form the primary structure. So, the initial entities are:
#     * Person (general category)
#     * Easy to Measure Person
#     * Hard to Measure Person
#     * Immeasurable Person
#
# 3. **Analyze Each Entity Type:** Go through the descriptions of each person type and identify their defining characteristics. These characteristics will become attributes of the entities.
#
#     * **Easy to Measure Person:**  The description focuses on negative qualities of mind and behavior. These translate into attributes:
#         * High-strung
#         * Rowdy
#         * Unruly
#         * Talkative
#         * Loose Words (consider grouping related concepts)
#         * Muddled Mindfulness
#         * Unalert
#         * Unconcentrated
#         * Scattered Mind
#         * Faculties Left Wide Open (consider this related to lack of control)
#
#     * **Hard to Measure Person:** This is essentially the opposite of the "easy to measure" person, with positive qualities.
#         * Not High-strung
#         * Not Rowdy
#         * Not Unruly
#         * Not Talkative
#         * Not Loose Words
#         * Established Mindfulness
#         * Alert
#         * Concentrated
#         * Mind Gathered into Singleness
#         * Restrained Faculties
#
#     * **Immeasurable Person:** This is defined by the attainment of Arahantship.
#         * Arahant
#         * Effluents Ended (This is a key Buddhist concept that needs its own entry)
#
# 4. **Identify Relationships:** Look for verbs or phrases that connect the entities and their attributes.
#
#     * The descriptions *are* the relationship between the person type and their characteristics. This can be represented as a "has_characteristic" relationship.
#     * The "is a" relationship connects the specific person types to the general "Person" category.
#     * The "Immeasurable Person" is explicitly defined as a "monk" who is an "arahant." This implies an "is_a" relationship with "Monk" and "has_attainment" relationship with "Arahant."
#
# 5. **Refine and Structure:** Organize the identified entities and relationships into the requested Python dictionary format. Think about how to represent the relationships clearly. Using lists of related entities within each entity's dictionary seems like a good approach.
#
# 6. **Consider Additional Concepts:**  As the user requested, think about if there are missing elements. The concept of "Effluents" is crucial in Buddhism and directly tied to the "Immeasurable Person." It needs to be included as an entity.
#
# 7. **Address the User's Goals:** Reflect on how the extracted ontology helps the user understand the Buddhist perspective on human experience. The descriptions highlight different states of mind and behavior, which are central to Buddhist teachings on the path to liberation.
#
# 8. **Review and Iterate:**  Read through the generated dictionary and the sutta again to ensure accuracy and completeness. Are there any other implicit relationships or entities? For instance, the concept of "measurement" is central, but it's more of a framing device than a core entity within the individuals themselves. The focus is on the *qualities* that make them measurable or immeasurable.
#
# 9. **Format the Output:** Ensure the Python dictionary is correctly formatted and easy to understand. Use clear and descriptive keys.
#
# This step-by-step process, focusing on identifying entities, their attributes, and the relationships between them, allows for a systematic extraction of the ontology from the given text. The iterative review helps catch any missed concepts and ensures the output meets the user's stated goals.
# ```python
# ontology = {
#     "entities": {
#         "Person": {
#             "description": "A general category for beings, in this context referring to individuals.",
#             "relationships": {
#                 "has_type": ["Easy to Measure Person", "Hard to Measure Person", "Immeasurable Person"]
#             }
#         },
#         "Easy to Measure Person": {
#             "description": "A type of person characterized by observable and quantifiable negative mental and behavioral traits.",
#             "attributes": [
#                 "high-strung",
#                 "rowdy",
#                 "unruly",
#                 "talkative",
#                 "of loose words",
#                 "muddled mindfulness",
#                 "unalert",
#                 "unconcentrated",
#                 "mind scattered",
#                 "faculties left wide open"
#             ],
#             "relationships": {
#                 "is_a_type_of": "Person"
#             }
#         },
#         "Hard to Measure Person": {
#             "description": "A type of person characterized by the absence of negative traits and the presence of positive mental qualities, making them less easily assessed superficially.",
#             "attributes": [
#                 "not high-strung",
#                 "not rowdy",
#                 "not unruly",
#                 "not talkative",
#                 "not of loose words",
#                 "mindfulness established",
#                 "alert",
#                 "concentrated",
#                 "mind gathered into singleness",
#                 "faculties restrained"
#             ],
#             "relationships": {
#                 "is_a_type_of": "Person"
#             }
#         },
#         "Immeasurable Person": {
#             "description": "A type of person, specifically an Arahant, whose inner state is beyond ordinary measurement due to the eradication of mental defilements.",
#             "attributes": [
#                 "arahant",
#                 "effluents ended"
#             ],
#             "relationships": {
#                 "is_a_type_of": "Person",
#                 "is_a": "Monk",
#                 "has_state": "Effluents Ended"
#             }
#         },
#         "Monk": {
#             "description": "A person who has renounced worldly life and practices the teachings of the Buddha.",
#             "relationships": {
#                 "can_be_type": ["Immeasurable Person"]
#             }
#         },
#         "Effluents": {
#             "description": "Mental defilements or impurities that flow out and disturb the mind. Their ending signifies liberation.",
#             "relationships": {
#                 "state_of": ["Immeasurable Person"]
#             }
#         },
#         "Mindfulness": {
#             "description": "The state of being aware of something.",
#             "relationships": {
#                 "can_be_qualified_by": ["muddled", "established"]
#             }
#         },
#         "Concentration": {
#             "description": "The ability to focus the mind on a single object.",
#             "relationships": {
#                 "can_be_qualified_by": ["unconcentrated", "concentrated"]
#             }
#         },
#         "Faculties": {
#             "description": "The six senses: eye, ear, nose, tongue, body, and mind.",
#             "relationships": {
#                 "can_be_in_state": ["left wide open", "restrained"],
#                 "part_of": "Person"
#             }
#         },
#         "Arahantship": {
#             "description": "The state of being an Arahant, a fully enlightened being who has eradicated all mental defilements.",
#             "relationships": {
#                 "attained_by": "Immeasurable Person"
#             }
#         }
#     },
#     "relationships": {
#         "has_type": {"description": "Indicates a specific category or type within a broader entity."},
#         "is_a_type_of": {"description": "Indicates that an entity belongs to a more general category."},
#         "is_a": {"description": "Indicates a direct identity or membership."},
#         "has_attribute": {"description": "Indicates a quality or characteristic of an entity."},
#         "has_state": {"description": "Indicates a condition or status of an entity."},
#         "can_be_type": {"description": "Indicates a potential category for an entity."},
#         "state_of": {"description": "Indicates the entity whose state is being described."},
#         "can_be_qualified_by": {"description": "Indicates a modifier or descriptor of an entity."},
#         "part_of": {"description": "Indicates that an entity is a component of another entity."},
#         "attained_by": {"description": "Indicates the entity that has achieved a certain state."}
#     }
# }
# ```
#
# **Explanation and Considerations:**
#
# This dictionary represents a preliminary ontology extracted from the provided sutta. Here's a breakdown of the choices made and how they relate to your goals:
#
# **Entities:**
#
# * **Person:**  A fundamental entity representing the individuals being discussed. We identify different types of people.
# * **Easy to Measure Person, Hard to Measure Person, Immeasurable Person:** These are the core categories defined in the sutta. Their descriptions are directly derived from the text.
# * **Monk:**  Specifically mentioned in the context of the "Immeasurable Person," indicating a role or status.
# * **Effluents:**  A crucial Buddhist concept directly linked to the definition of an Arahant. It's important to include this as it's central to the "immeasurability."
# * **Mindfulness, Concentration, Faculties:** These are mental qualities or capacities discussed in the descriptions of the different person types. Treating them as entities allows us to explore their attributes and relationships.
# * **Arahantship:** The state of being an Arahant, representing the culmination of spiritual practice.
#
# **Relationships:**
#
# * **`has_type` and `is_a_type_of`:** These establish the hierarchical relationship between the general "Person" and the specific types.
# * **`is_a`:**  Used for direct identity or membership, like an "Immeasurable Person" *is a* "Monk."
# * **`has_attribute`:** Links the person types to their defining characteristics. While not explicitly listed as "has_attribute" in the dictionary's entities section, the `attributes` lists implicitly represent this relationship. You could further refine this by adding `has_attribute` relationships in the "relationships" section and linking attributes as entities if needed for more granularity.
# * **`has_state`:**  Specifically used for "Effluents Ended," as this describes a condition of the "Immeasurable Person."
# * **`can_be_type`:** Indicates a potential category membership.
# * **`state_of`:** Connects "Effluents" to the "Immeasurable Person."
# * **`can_be_qualified_by`:**  Used for descriptors of "Mindfulness" and "Concentration."
# * **`part_of`:** Indicates a component relationship, like "Faculties" being part of a "Person."
# * **`attained_by`:** Connects "Arahantship" to the "Immeasurable Person."
#
# **How this addresses your goals:**
#
# * **Identifying Entities and Relationships:** The dictionary explicitly lists entities and the relationships between them, forming the basis of your desired graph structure.
# * **Understanding Buddhist Ontology:** The extracted entities and relationships represent key concepts within this specific sutta and broader Buddhist thought. You can start to see how different mental states and levels of spiritual development are categorized.
# * **Metaphor and Meaning:** By identifying the attributes and relationships, you can begin to understand the *meaning* behind the descriptions. For example, "muddled mindfulness" is contrasted with "established mindfulness," pointing to a desired mental state in Buddhist practice. The "immeasurability" of the Arahant is directly tied to the "ending of effluents," highlighting the transformative effect of spiritual practice.
# * **Graph Structure for RAG:** The dictionary format can be easily transformed into a graph database (e.g., using libraries like `networkx` in Python) where entities are nodes and relationships are edges. This graph can then be used for RAG, where you can retrieve relevant information based on the connections between concepts.
#
# **Potential Improvements and Considerations for Future Suttas:**
#
# * **Granularity of Attributes:**  You might decide to treat some attributes as entities themselves if they are complex concepts. For example, "muddled mindfulness" could become an entity with its own attributes.
# * **Implicit Relationships:**  The sutta implies a progression or a goal in moving from the "Easy to Measure" to the "Hard to Measure" and ultimately the "Immeasurable." You might consider adding relationships like "potential_for" or "path_to."
# * **Contextual Information:**  Consider adding the sutta name or reference as metadata to the ontology.
# * **Overlapping Concepts:** As you process more suttas, you'll encounter overlapping concepts. You'll need a strategy for merging or linking these concepts in your overall ontology.
# * **Nuance and Interpretation:**  Remember that language, especially in ancient texts, can have multiple layers of meaning. Your ontology will be an interpretation based on the text.
#
# This initial ontology provides a solid foundation for your exploration of Buddhist concepts. As you process more suttas, your understanding of the underlying ontology will become richer and more nuanced.

# %%
bad_thinking = []
data_thinking = data_thinking.to_dicts()
for el_ in tqdm(data_thinking):
    try:
        el_["model_output"] = model_thinking.generate_content(
            el_["text"]
        ).text
        el_["model_name"] = model_thinking.model_name
        el_["prompt_type"] = "thinking"

        if PRINT == False:
            with jsonlines.open(write_path, mode='a') as writer:
                writer.write(el_) 
    except Exception as e:
        print(f"""{el_["sutta"]}: {e}""")
        bad_thinking.append(el_)
# Out:
#   0%|          | 0/1395 [00:00<?, ?it/s]
# DN 16: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting
# Thig 6:8: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 4. Meaning that the model was reciting from copyrighted material.
# AN 3:131: 429 Resource has been exhausted (e.g. check quota).
# SN 48:53: 429 Resource has been exhausted (e.g. check quota).
# AN 3:137: 429 Resource has been exhausted (e.g. check quota).
# Khp 5: 429 Resource has been exhausted (e.g. check quota).
# SN 41:10: 429 Resource has been exhausted (e.g. check quota).
# AN 3:68: 429 Resource has been exhausted (e.g. check quota).
# SN 27:3: 429 Resource has been exhausted (e.g. check quota).
# Khp 2: 429 Resource has been exhausted (e.g. check quota).
# SN 22:86: 429 Resource has been exhausted (e.g. check quota).
# AN 5:148: 429 Resource has been exhausted (e.g. check quota).
# AN 3:101: 429 Resource has been exhausted (e.g. check quota).
# AN 4:77: 429 Resource has been exhausted (e.g. check quota).
# MN 1: 429 Resource has been exhausted (e.g. check quota).
# AN 3:129: 429 Resource has been exhausted (e.g. check quota).
# AN 5:196: 429 Resource has been exhausted (e.g. check quota).
# AN 6:70: 429 Resource has been exhausted (e.g. check quota).
# SN 55:30: 429 Resource has been exhausted (e.g. check quota).
# Sn 4:3: 429 Resource has been exhausted (e.g. check quota).
# SN 21:1: 429 Resource has been exhausted (e.g. check quota).
# AN 4:125: 429 Resource has been exhausted (e.g. check quota).
# SN 35:63: 429 Resource has been exhausted (e.g. check quota).
# Thag 6:13: 429 Resource has been exhausted (e.g. check quota).
# SN 3:25: 429 Resource has been exhausted (e.g. check quota).
# Ud 5:6: 429 Resource has been exhausted (e.g. check quota).
# SN 6:14: 429 Resource has been exhausted (e.g. check quota).
# SN 3:7: 429 Resource has been exhausted (e.g. check quota).
# Khp 6: 429 Resource has been exhausted (e.g. check quota).
# Thig 8: 429 Resource has been exhausted (e.g. check quota).
# Thig 6:7: 429 Resource has been exhausted (e.g. check quota).
# SN 22:121: 429 Resource has been exhausted (e.g. check quota).
# MN 118: 429 Resource has been exhausted (e.g. check quota).
# AN 3:121: 429 Resource has been exhausted (e.g. check quota).
# SN 56:1: 429 Resource has been exhausted (e.g. check quota).
# AN 3:93: 429 Resource has been exhausted (e.g. check quota).
# AN 4:126: 429 Resource has been exhausted (e.g. check quota).
# Thag 2:27: 429 Resource has been exhausted (e.g. check quota).
# Iti 102: 429 Resource has been exhausted (e.g. check quota).
# SN 36:11: 429 Resource has been exhausted (e.g. check quota).
# AN 5:121: 429 Resource has been exhausted (e.g. check quota).
# MN 64: 429 Resource has been exhausted (e.g. check quota).
# Thag 13: 429 Resource has been exhausted (e.g. check quota).
# MN 51: 429 Resource has been exhausted (e.g. check quota).
# Thag 1:14: 429 Resource has been exhausted (e.g. check quota).
# Sn 5:3: 429 Resource has been exhausted (e.g. check quota).
# SN 54:6: 429 Resource has been exhausted (e.g. check quota).
# Sn 3:5: 429 Resource has been exhausted (e.g. check quota).
# SN 16:2: 429 Resource has been exhausted (e.g. check quota).
# SN 56:102: 429 Resource has been exhausted (e.g. check quota).
# SN 56:46: 429 Resource has been exhausted (e.g. check quota).
# Iti 109: 429 Resource has been exhausted (e.g. check quota).
# SN 46:14: 429 Resource has been exhausted (e.g. check quota).
# AN 3:71: 429 Resource has been exhausted (e.g. check quota).
# MN 24: 429 Resource has been exhausted (e.g. check quota).
# AN 9:31: 429 Resource has been exhausted (e.g. check quota).
# AN 5:162: 429 Resource has been exhausted (e.g. check quota).
# AN 6:92: 429 Resource has been exhausted (e.g. check quota).
# AN 4:138: 429 Resource has been exhausted (e.g. check quota).
# SN 22:53: 429 Resource has been exhausted (e.g. check quota).
# AN 10:48: 429 Resource has been exhausted (e.g. check quota).
# Thig 12: 429 Resource has been exhausted (e.g. check quota).
# Thag 3:14: 429 Resource has been exhausted (e.g. check quota).
# SN 5:5: 429 Resource has been exhausted (e.g. check quota).
# AN 8:70: 429 Resource has been exhausted (e.g. check quota).
# SN 46:11: 429 Resource has been exhausted (e.g. check quota).
# AN 3:34: 429 Resource has been exhausted (e.g. check quota).
# Ch. 15 Happy: 429 Resource has been exhausted (e.g. check quota).
# SN 12:20: 429 Resource has been exhausted (e.g. check quota).
# Iti 78: 429 Resource has been exhausted (e.g. check quota).
# MN 70: 429 Resource has been exhausted (e.g. check quota).
# SN 51:15: 429 Resource has been exhausted (e.g. check quota).
# Sn 4:1: 429 Resource has been exhausted (e.g. check quota).
# SN 16:5: 429 Resource has been exhausted (e.g. check quota).
# SN 46:4: 429 Resource has been exhausted (e.g. check quota).
# Ud 2:1: 429 Resource has been exhausted (e.g. check quota).
# Ud 2:5: 429 Resource has been exhausted (e.g. check quota).
# AN 6:12: 429 Resource has been exhausted (e.g. check quota).
# Sn 4:16: 429 Resource has been exhausted (e.g. check quota).
# Ch. 23 Elephants: 429 Resource has been exhausted (e.g. check quota).
# AN 5:179: 429 Resource has been exhausted (e.g. check quota).
# SN 55:22: 429 Resource has been exhausted (e.g. check quota).
# MN 54: 429 Resource has been exhausted (e.g. check quota).
# AN 4:158: 429 Resource has been exhausted (e.g. check quota).
# SN 22:56: 429 Resource has been exhausted (e.g. check quota).
# AN 3:85: 429 Resource has been exhausted (e.g. check quota).
# SN 3:2: 429 Resource has been exhausted (e.g. check quota).
# AN 6:83: 429 Resource has been exhausted (e.g. check quota).
# Thag 10:7: 429 Resource has been exhausted (e.g. check quota).
# Ud 5:10: 429 Resource has been exhausted (e.g. check quota).
# AN 7:49: 429 Resource has been exhausted (e.g. check quota).
# AN 11:16: 429 Resource has been exhausted (e.g. check quota).
# Ud 2:9: 429 Resource has been exhausted (e.g. check quota).
# AN 4:111: 429 Resource has been exhausted (e.g. check quota).
# Sn 2:8: 429 Resource has been exhausted (e.g. check quota).
# SN 56:31: 429 Resource has been exhausted (e.g. check quota).
# AN 4:41: 429 Resource has been exhausted (e.g. check quota).
# SN 35:82: 429 Resource has been exhausted (e.g. check quota).
# Khp 7: 429 Resource has been exhausted (e.g. check quota).
# Iti 15: 429 Resource has been exhausted (e.g. check quota).
# Thag 12:2: 429 Resource has been exhausted (e.g. check quota).
# AN 4:184: 429 Resource has been exhausted (e.g. check quota).
# Iti 18: 429 Resource has been exhausted (e.g. check quota).
# SN 35:117: 429 Resource has been exhausted (e.g. check quota).
# SN 35:69: 429 Resource has been exhausted (e.g. check quota).
# AN 7:54: 429 Resource has been exhausted (e.g. check quota).
# AN 9:15: 429 Resource has been exhausted (e.g. check quota).
# AN 3:61: 429 Resource has been exhausted (e.g. check quota).
# Thag 2:11: 429 Resource has been exhausted (e.g. check quota).
# Thag 1:114: 429 Resource has been exhausted (e.g. check quota).
# AN 3:104: 429 Resource has been exhausted (e.g. check quota).
# SN 46:5: 429 Resource has been exhausted (e.g. check quota).
# SN 1:63: 429 Resource has been exhausted (e.g. check quota).
# Iti 81: 429 Resource has been exhausted (e.g. check quota).
# AN 3:33: 429 Resource has been exhausted (e.g. check quota).
# AN 4:183: 429 Resource has been exhausted (e.g. check quota).
# AN 4:36: 429 Resource has been exhausted (e.g. check quota).
# AN 4:117: 429 Resource has been exhausted (e.g. check quota).
# Ch. 6 The Wise: 429 Resource has been exhausted (e.g. check quota).
# Thag 1:57: 429 Resource has been exhausted (e.g. check quota).
# AN 5:175: 429 Resource has been exhausted (e.g. check quota).
# AN 6:63: 429 Resource has been exhausted (e.g. check quota).
# SN 47:25: 429 Resource has been exhausted (e.g. check quota).
# SN 48:4: 429 Resource has been exhausted (e.g. check quota).
# AN 4:233: 429 Resource has been exhausted (e.g. check quota).
# Sn 1:4: 429 Resource has been exhausted (e.g. check quota).
# AN 5:38: 429 Resource has been exhausted (e.g. check quota).
# Thig 1:17: 429 Resource has been exhausted (e.g. check quota).
# Thag 2:13: 429 Resource has been exhausted (e.g. check quota).
# AN 1:329: 429 Resource has been exhausted (e.g. check quota).
# AN 2:31: 429 Resource has been exhausted (e.g. check quota).
# AN 3:40: 429 Resource has been exhausted (e.g. check quota).
# Ch. 4 Blossoms: 429 Resource has been exhausted (e.g. check quota).
# SN 1:56: 429 Resource has been exhausted (e.g. check quota).
# Ud 6:6: 429 Resource has been exhausted (e.g. check quota).
# Thag 1:104: 429 Resource has been exhausted (e.g. check quota).
# Iti 103: 429 Resource has been exhausted (e.g. check quota).
# Thag 1:1: 429 Resource has been exhausted (e.g. check quota).
# DN 29: 429 Resource has been exhausted (e.g. check quota).
# MN 151: 429 Resource has been exhausted (e.g. check quota).
# Iti 66: 429 Resource has been exhausted (e.g. check quota).
# Ud 3:8: 429 Resource has been exhausted (e.g. check quota).
# Iti 80: 429 Resource has been exhausted (e.g. check quota).
# Ud 7:4: 429 Resource has been exhausted (e.g. check quota).
# Thag 6:3: 429 Resource has been exhausted (e.g. check quota).
# Ch. 22 Hell: 429 Resource has been exhausted (e.g. check quota).
# MN 61: 429 Resource has been exhausted (e.g. check quota).
# AN 7:32: 429 Resource has been exhausted (e.g. check quota).
# SN 20:4: 429 Resource has been exhausted (e.g. check quota).
# SN 3:14: 429 Resource has been exhausted (e.g. check quota).
# Sn 4:11: 429 Resource has been exhausted (e.g. check quota).
# Sn 2:5: 429 Resource has been exhausted (e.g. check quota).
# Sn 4:9: 429 Resource has been exhausted (e.g. check quota).
# SN 48:39: 429 Resource has been exhausted (e.g. check quota).
# Ud 8:4: 429 Resource has been exhausted (e.g. check quota).
# SN 5:1: 429 Resource has been exhausted (e.g. check quota).
# Iti 17: 429 Resource has been exhausted (e.g. check quota).
# SN 35:198: 429 Resource has been exhausted (e.g. check quota).
# MN 72: 429 Resource has been exhausted (e.g. check quota).
# AN 4:238: 429 Resource has been exhausted (e.g. check quota).
# SN 2:23: 429 Resource has been exhausted (e.g. check quota).
# MN 137: 429 Resource has been exhausted (e.g. check quota).
# SN 3:22: 429 Resource has been exhausted (e.g. check quota).
# AN 9:63: 429 Resource has been exhausted (e.g. check quota).
# SN 8:4: 429 Resource has been exhausted (e.g. check quota).
# SN 45:2: 429 Resource has been exhausted (e.g. check quota).
# AN 5:198: 429 Resource has been exhausted (e.g. check quota).
# Sn 4:8: 429 Resource has been exhausted (e.g. check quota).
# SN 22:79: 429 Resource has been exhausted (e.g. check quota).
# MN 59: 429 Resource has been exhausted (e.g. check quota).
# AN 6:74: 429 Resource has been exhausted (e.g. check quota).
# Ch. 18 Impurities: 429 Resource has been exhausted (e.g. check quota).
# AN 10:104: 429 Resource has been exhausted (e.g. check quota).
# AN 6:38: 429 Resource has been exhausted (e.g. check quota).
# AN 10:93: 429 Resource has been exhausted (e.g. check quota).
# AN 8:51: 429 Resource has been exhausted (e.g. check quota).
# AN 4:24: 429 Resource has been exhausted (e.g. check quota).
# Iti 36: 429 Resource has been exhausted (e.g. check quota).
# SN 12:63: 429 Resource has been exhausted (e.g. check quota).
# Iti 58: 429 Resource has been exhausted (e.g. check quota).
# Khp 4: 429 Resource has been exhausted (e.g. check quota).
# Thag 1:93: 429 Resource has been exhausted (e.g. check quota).
# AN 5:130: 429 Resource has been exhausted (e.g. check quota).
# Thag 1:118: 429 Resource has been exhausted (e.g. check quota).
# Thag 1:25: 429 Resource has been exhausted (e.g. check quota).
# MN 12: 429 Resource has been exhausted (e.g. check quota).
# Thag 3:8: 429 Resource has been exhausted (e.g. check quota).
# Thag 16:4: 429 Resource has been exhausted (e.g. check quota).
# SN 47:13: 429 Resource has been exhausted (e.g. check quota).
# Ud 6:5: 429 Resource has been exhausted (e.g. check quota).
# AN 3:73: 429 Resource has been exhausted (e.g. check quota).
# AN 8:39: 429 Resource has been exhausted (e.g. check quota).
# AN 4:42: 429 Resource has been exhausted (e.g. check quota).
# AN 10:46: 429 Resource has been exhausted (e.g. check quota).
# Sn 5:7: 429 Resource has been exhausted (e.g. check quota).
# Ud 8:9: 429 Resource has been exhausted (e.g. check quota).
# SN 54:12: 429 Resource has been exhausted (e.g. check quota).
# SN 22:127: 429 Resource has been exhausted (e.g. check quota).
